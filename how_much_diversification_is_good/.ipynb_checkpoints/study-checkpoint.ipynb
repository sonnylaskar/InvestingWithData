# %% [markdown]
# #SIMULATION STUDY TO UNDERSTAND HOW MUCH DIVERSIFICATION IS GOOD

# %%
import requests
import pandas as pd
import numpy as np
import pickle
import pytz
import random
from datetime import datetime, timedelta
from collections import defaultdict 
import time

import matplotlib.pyplot as plt
import seaborn as sns
import uuid
import os
import glob

# %%
FYERS_APP_ID = '<INSERT>'
FYERS_ACCESS_TOKEN = '<INSERT>'

# %%
def getPrice(symbol, from_date, to_date):
    API_ENDPOINT = "https://api.fyers.in/data-rest/v2/history/"
    headers = {
        "Authorization": f"{FYERS_APP_ID}:{FYERS_ACCESS_TOKEN}"
    }
    params = {
        "symbol": symbol,
        "resolution": "1D",
        "date_format": "1",
        "range_from": from_date,
        "range_to": to_date,
        "cont_flag": "1"
    }
    r1 = requests.get(API_ENDPOINT, headers=headers, params=params)
    
    data = r1.json()
    if data['s'] != 'ok':
        return pd.DataFrame()
    candles = data['candles']
    if len(candles) == 0:
        print("ErrorCode", data['code'], data['message'], symbol, from_date, to_date)
        return pd.DataFrame()
    
    df = pd.DataFrame(candles, columns=["time", "open", "high", "low", "close", "volume"])
    df['time'] = pd.to_datetime(df['time'], unit='s').dt.tz_localize(pytz.utc).dt.tz_convert('Asia/Kolkata')
    df['time'] = df['time'].dt.strftime('%Y-%m-%d %H:%M:%S')
    return df

# %%
def getNifty100Stocks(file_path):
    try:
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Extract the values from the "Symbol" column and convert them to a list
        symbols = df['Symbol'].tolist()
        
        return symbols
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Usage example
file_path = 'ind_nifty100list.csv' #'https://nsearchives.nseindia.com/content/indices/ind_nifty100list.csv'
symbol_list = getNifty100Stocks(file_path)

# Print the list of symbols
print(symbol_list)
# Out:
# ['ABB', 'ADANIENSOL', 'ADANIENT', 'ADANIGREEN', 'ADANIPORTS', 'ATGL', 'AWL', 'AMBUJACEM', 'APOLLOHOSP', 'ASIANPAINT', 'DMART', 'AXISBANK', 'BAJAJ-AUTO', 'BAJFINANCE', 'BAJAJFINSV', 'BAJAJHLDNG', 'BANKBARODA', 'BERGEPAINT', 'BEL', 'BPCL', 'BHARTIARTL', 'BOSCHLTD', 'BRITANNIA', 'CANBK', 'CHOLAFIN', 'CIPLA', 'COALINDIA', 'COLPAL', 'DLF', 'DABUR', 'DIVISLAB', 'DRREDDY', 'EICHERMOT', 'GAIL', 'GODREJCP', 'GRASIM', 'HCLTECH', 'HDFCBANK', 'HDFCLIFE', 'HAVELLS', 'HEROMOTOCO', 'HINDALCO', 'HAL', 'HINDUNILVR', 'ICICIBANK', 'ICICIGI', 'ICICIPRULI', 'ITC', 'IOC', 'IRCTC', 'INDUSINDBK', 'NAUKRI', 'INFY', 'INDIGO', 'JSWSTEEL', 'JINDALSTEL', 'KOTAKBANK', 'LTIM', 'LT', 'LICI', 'M&M', 'MARICO', 'MARUTI', 'MUTHOOTFIN', 'NTPC', 'NESTLEIND', 'ONGC', 'PIIND', 'PIDILITIND', 'POWERGRID', 'PGHH', 'PNB', 'RELIANCE', 'SBICARD', 'SBILIFE', 'SRF', 'MOTHERSON', 'SHREECEM', 'SHRIRAMFIN', 'SIEMENS', 'SBIN', 'SUNPHARMA', 'TVSMOTOR', 'TCS', 'TATACONSUM', 'TATAMTRDVR', 'TATAMOTORS', 'TATAPOWER', 'TATASTEEL', 'TECHM', 'TITAN', 'TORNTPHARM', 'TRENT', 'UPL', 'ULTRACEMCO', 'MCDOWELL-N', 'VBL', 'VEDL', 'WIPRO', 'ZOMATO', 'ZYDUSLIFE']

# %%
def didStockUndergoSplit(df, price_change_threshold=50):
    # Calculate daily percentage change in closing price
    df['priceChange'] = df['close'].pct_change() * 100  # Percentage change

    # Find rows where the percentage change exceeds the threshold
    split_candidates = df[df['priceChange'].abs() > price_change_threshold]
    if split_candidates.shape[0] > 0:
        return True
    else:
        return False

# %%
investment_per_stock = 100000

# %%
for _ in range(20):
    returns = defaultdict(defaultdict)
    for year in range(2015, 2023, 1):
        #print(year)
        random_symbols = random.sample(symbol_list, 100)
        #print(random_symbols)
        from_date_str = str(year) + '-01-01'
        to_date_str = str(year) + '-12-30'
        counter = 0
        cummulative_return = 0
        for symbol in random_symbols:
            if len(returns[year]) >= 30:
                break
            print(year, symbol)
            dat = getPrice('NSE:' + symbol + '-EQ', from_date_str, to_date_str)
            time.sleep(0.5)
            if dat.shape[0] == 0:
                continue
            if didStockUndergoSplit(dat):
                continue
            no_of_shares = int(investment_per_stock / dat.iloc[0]['close'])
            current_return = no_of_shares * (dat.iloc[-1]['close'] - dat.iloc[0]['close'])
            cummulative_return += current_return
            cummulative_roi = cummulative_return / (investment_per_stock * (counter + 1)) * 100
            returns[year][counter] = {
                'symbol': symbol,
                'entry_date': dat.iloc[0]['time'][0:10], 
                'exit_date': dat.iloc[-1]['time'][0:10],
                'entry_price': dat.iloc[0]['close'],
                'exit_price': dat.iloc[-1]['close'],
                'no_of_shares': no_of_shares,
                'return': current_return,
                'cummulative_return': cummulative_return,
                'cummulative_roi': cummulative_roi

            }
            counter += 1
    # Create a list of dictionaries with year and subkey as keys
    data = []
    for year, subkeys in returns.items():
        for subkey, subvalue in subkeys.items():
            data.append({'year': year, 'symbol#': subkey + 1, **subvalue})

    # Create the DataFrame
    df = pd.DataFrame(data)
    df.to_csv(f'simulation/simulation_{uuid.uuid1()}.csv') #save to disk
# Out:
# 2015 SBIN
# 2015 DIVISLAB
# 2015 ZOMATO
# 2015 HDFCBANK
# 2015 INDIGO
# 2015 BPCL
# 2015 ADANIENSOL
# 2015 ADANIPORTS
# 2015 LICI
# 2015 APOLLOHOSP
# 2015 TATAMTRDVR
# 2015 TRENT
# 2015 BEL
# 2015 TATASTEEL
# 2015 BANKBARODA
# 2015 AMBUJACEM
# 2015 SUNPHARMA
# 2015 HAVELLS
# 2015 ADANIGREEN
# 2015 TATAPOWER
# 2015 TECHM
# 2015 RELIANCE
# 2015 ICICIPRULI
# 2015 NAUKRI
# 2015 BOSCHLTD
# 2015 BAJAJ-AUTO
# 2015 PGHH
# 2015 DLF
# 2015 ULTRACEMCO
# 2019 ASIANPAINT
# 2019 BEL
# 2019 ADANIENSOL
# 2019 ATGL
# 2020 INDIGO
# 2020 ABB
# 2020 PIIND
# 2020 SBILIFE
# 2020 DIVISLAB
# 2020 VBL
# 2020 COLPAL
# 2020 TCS
# 2020 ADANIGREEN
# 2020 BPCL
# 2020 AWL
# 2020 MOTHERSON
# 2020 TATACONSUM
# 2020 BOSCHLTD
# 2020 HAL
# 2020 ULTRACEMCO
# 2020 NAUKRI
# 2020 BAJAJ-AUTO
# 2020 TRENT
# 2020 APOLLOHOSP
# 2020 ADANIPORTS
# 2020 SIEMENS
# 2020 TECHM
# 2020 HEROMOTOCO
# 2020 SHREECEM
# 2020 VEDL
# 2020 IRCTC
# 2020 UPL
# 2020 INDUSINDBK
# 2020 DMART
# 2020 SBICARD
# 2021 MARICO
# 2021 SUNPHARMA
# 2021 COALINDIA
# 2021 TATAMTRDVR
# 2021 TATASTEEL
# 2021 TVSMOTOR
# 2021 BPCL
# 2021 DRREDDY
# 2021 LT
# 2021 ASIANPAINT
# 2021 TITAN
# 2021 ADANIENT
# 2021 AXISBANK
# 2021 BAJAJFINSV
# 2021 PIIND
# 2021 BAJFINANCE
# 2021 ICICIBANK
# 2021 MUTHOOTFIN
# 2021 LTIM
# 2021 APOLLOHOSP
# 2021 HINDUNILVR
# 2021 TATACONSUM
# 2021 KOTAKBANK
# 2021 HINDALCO
# 2021 HDFCLIFE
# 2021 PGHH
# 2021 IRCTC
# 2021 HCLTECH
# 2021 ULTRACEMCO
# 2021 AMBUJACEM
# 2022 TATASTEEL
# 2022 BPCL
# 2022 HAL
# 2022 ADANIPORTS
# 2022 INDUSINDBK
# 2022 ICICIPRULI
# 2022 TVSMOTOR
# 2022 SBIN
# 2022 CIPLA
# 2022 BHARTIARTL
# 2022 MARUTI
# 2022 TITAN
# 2022 TATAPOWER
# 2022 ASIANPAINT
# 2022 SBICARD
# 2022 SBILIFE
# 2022 ADANIGREEN
# 2022 BAJAJHLDNG
# 2022 WIPRO
# 2022 SHREECEM
# 2022 HDFCLIFE
# 2022 SIEMENS
# 2022 NAUKRI
# 2022 PNB
# 2022 CANBK
# 2022 AXISBANK
# 2022 BEL
# 2022 MCDOWELL-N
# 2022 SRF
# 2022 TORNTPHARM

# %%
# Define the directory path
directory_path = 'simulation'  # Replace with the actual directory path
# Use glob to find all CSV files in the directory
csv_files = glob.glob(os.path.join(directory_path, 'simulation*.csv'))
csv_files
# Out:
# ['simulation\\simulation_0841b3a6-70bb-11ee-bedd-88d82ed50e02.csv',
#  'simulation\\simulation_1e3300a6-70b4-11ee-a6e8-88d82ed50e02.csv',
#  'simulation\\simulation_1e80b0ef-70bc-11ee-a602-88d82ed50e02.csv',
#  'simulation\\simulation_383f27f7-70bd-11ee-adc4-88d82ed50e02.csv',
#  'simulation\\simulation_3f80f1d2-70b2-11ee-81c6-88d82ed50e02.csv',
#  'simulation\\simulation_47706b03-70af-11ee-810b-88d82ed50e02.csv',
#  'simulation\\simulation_492ec0ce-70aa-11ee-8645-88d82ed50e02.csv',
#  'simulation\\simulation_5922deb1-70aa-11ee-9556-88d82ed50e02.csv',
#  'simulation\\simulation_5eb91b07-70b1-11ee-8024-88d82ed50e02.csv',
#  'simulation\\simulation_69187c52-70ae-11ee-9897-88d82ed50e02.csv',
#  'simulation\\simulation_6bc5e630-70ac-11ee-9bd1-88d82ed50e02.csv',
#  'simulation\\simulation_7b162a5c-70ba-11ee-ad71-88d82ed50e02.csv',
#  'simulation\\simulation_942069ad-70ad-11ee-ae4f-88d82ed50e02.csv',
#  'simulation\\simulation_96094bd9-70bb-11ee-a960-88d82ed50e02.csv',
#  'simulation\\simulation_aaf25d2d-70bc-11ee-8cf2-88d82ed50e02.csv',
#  'simulation\\simulation_afb4c590-70b6-11ee-9bdf-88d82ed50e02.csv',
#  'simulation\\simulation_cfbd0c46-70b5-11ee-953e-88d82ed50e02.csv',
#  'simulation\\simulation_eee33ea1-70b9-11ee-aa09-88d82ed50e02.csv',
#  'simulation\\simulation_ef54c3d5-70b7-11ee-a86a-88d82ed50e02.csv',
#  'simulation\\simulation_fa922b7d-70b4-11ee-a872-88d82ed50e02.csv']

# %%
#See plot of any individual simulation
df = pd.read_csv(csv_files[0])
# Group by 'year' and 'symbol#' and calculate the mean of 'cummulative_roi'
mean_roi = df.groupby(['symbol#'])['cummulative_roi'].mean().reset_index()

# Define a custom color palette for the lines
custom_palette = sns.color_palette("hsv", n_colors=len(df['year'].unique()))

# Create a line chart using Seaborn with the custom color palette
plt.figure(figsize=(10, 6))
sns.lineplot(x='symbol#', y='cummulative_roi', hue='year', data=df, palette=custom_palette)

# Customize the plot
plt.xlabel('symbol#')
plt.ylabel('cummulative_roi')
plt.title('Cummulative ROI for Each Year for one simulation')
plt.legend(title='Year')

# Add horizontal lines at Y = 10 and Y = 20
plt.axhline(y=20, color='black', linestyle='--', label='Y = 20')

# Show only integer values on the X-axis
plt.xticks(range(int(df['symbol#'].min()), int(df['symbol#'].max()) + 1))

# Show the plot
plt.show()

# %%
# plot the cummulative across all years
plt.figure(figsize=(10, 6))
sns.lineplot(x='symbol#', y='cummulative_roi', data=mean_roi, marker='o')

# Customize the plot
plt.xlabel('symbol#')
plt.ylabel('Mean Cummulative ROI')
plt.title('Mean Cummulative ROI by Symbol# for one simulation')

# Show the plot
plt.show()

# %%
# Initialize an empty list to store DataFrames from each CSV file
dfs = []

# Read and merge all CSV files into a single DataFrame
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame (df_all)
df_all = pd.concat(dfs, ignore_index=True)

# Group by 'symbol#' and compute mean 'cummulative_roi'
mean_cummulative_roi = df_all.groupby('symbol#')['cummulative_roi'].mean().reset_index()

# Display the resulting DataFrame
# Create a line plot using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x='symbol#', y='cummulative_roi', data=mean_cummulative_roi, marker='o')

# Customize the plot
plt.xlabel('symbol#')
plt.ylabel('Mean Cummulative ROI')
plt.title('Mean Cummulative ROI by Symbol# aggregated across all simulations')

# Show the plot
plt.show()
